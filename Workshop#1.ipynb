# %% [markdown]
# # Fundamental Data Science for Data Scientist using Python

# %% [markdown]
# ## Workshop 1

# %% [markdown]
# ### Getting Data

# %%
#Import Python Libraries
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Getting data from titanic set

# %% [markdown]
# We are getting data from github....

# %%
df = pd.read_csv("titanic-train.csv")

df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Survived'].dtype
# Out:
# dtype('int64')

# %%
df['Pclass'].dtype
# Out:
# dtype('int64')

# %%
df['Survived'] = df['Survived'].astype('category')
df['Pclass'] = df['Pclass'].astype('category')

# %%
df['Survived'].dtype
# Out:
# CategoricalDtype(categories=[0, 1], ordered=False)

# %%
df['Pclass'].dtype
# Out:
# CategoricalDtype(categories=[1, 2, 3], ordered=False)

# %%
df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %%
df2 = df.dropna()

# %%
# %matplotlib inline

# %%
df.groupby(['Survived'])['Survived'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df.groupby(['Pclass'])['Pclass'].count().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
plt.hist(df2['Age'], bins=10, density=1)
# Out:
# (array([0.00691007, 0.00414604, 0.02211221, 0.0207302 , 0.02764027,
#         0.01658416, 0.01589315, 0.00898309, 0.00276403, 0.00069101]),
#  array([ 0.92 ,  8.828, 16.736, 24.644, 32.552, 40.46 , 48.368, 56.276,
#         64.184, 72.092, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df2['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(df2['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
sns.histplot(df2['SibSp'])
# Out:
# <Axes: xlabel='SibSp', ylabel='Count'>

# %%
sns.histplot(df2['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.set_style("whitegrid")

df.groupby(['Survived'])['Age'].mean().plot(kind='bar')

# %%
pd.plotting.scatter_matrix(df2, figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f772898>,
# ...
#       dtype=object)
