# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("files/WA_Fn-UseC_-Sales-Win-Loss.csv")
data.head()
# Out:
#    Opportunity Number     Supplies Subgroup          Supplies Group  \
# 0             1641984  Exterior Accessories         Car Accessories
# 1             1658010  Exterior Accessories         Car Accessories
# 2             1674737      Motorcycle Parts  Performance & Non-auto
# 3             1675224         Shelters & RV  Performance & Non-auto
# 4             1689785  Exterior Accessories         Car Accessories
#
#       Region Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0  Northwest    Fields Sales                           76                Won
# 1    Pacific        Reseller                           63               Loss
# 2    Pacific        Reseller                           24                Won
# 3    Midwest        Reseller                           16               Loss
# 4    Pacific        Reseller                           69               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# 1                         2                                    163
# 2                         7                                     82
# 3                         5                                    124
# 4                        11                                     91
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
# 2                                       82                    7750
# 3                                      124                       0
# 4                                       13                   69756
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
# 2                       1                              1
# 3                       1                              1
# 4                       1                              1
#
#    Revenue From Client Past Two Years Competitor Type  \
# 0                                   0         Unknown
# 1                                   0         Unknown
# 2                                   0         Unknown
# 3                                   0           Known
# 4                                   0         Unknown
#
#    Ratio Days Identified To Total Days  Ratio Days Validated To Total Days  \
# 0                              0.69636                            0.113985
# 1                              0.00000                            1.000000
# 2                              1.00000                            0.000000
# 3                              1.00000                            0.000000
# 4                              0.00000                            0.141125
#
#    Ratio Days Qualified To Total Days  Deal Size Category
# 0                            0.154215                   1
# 1                            0.000000                   1
# 2                            0.000000                   1
# 3                            0.000000                   1
# 4                            0.000000                   4

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(["Won", "Loss"])
list(le.classes_)
data['Opportunity'] = le.transform(data['Opportunity Result'])
data
# Out:
#        Opportunity Number        Supplies Subgroup          Supplies Group  \
# 0                 1641984     Exterior Accessories         Car Accessories
# 1                 1658010     Exterior Accessories         Car Accessories
# 2                 1674737         Motorcycle Parts  Performance & Non-auto
# 3                 1675224            Shelters & RV  Performance & Non-auto
# 4                 1689785     Exterior Accessories         Car Accessories
# ...                   ...                      ...                     ...
# 78020            10089932  Batteries & Accessories         Car Accessories
# 78021            10089961            Shelters & RV  Performance & Non-auto
# 78022            10090145     Exterior Accessories         Car Accessories
# 78023            10090430     Exterior Accessories         Car Accessories
# 78024            10094255     Interior Accessories         Car Accessories
#
#              Region Route To Market  Elapsed Days In Sales Stage  \
# 0         Northwest    Fields Sales                           76
# 1           Pacific        Reseller                           63
# 2           Pacific        Reseller                           24
# 3           Midwest        Reseller                           16
# 4           Pacific        Reseller                           69
# ...             ...             ...                          ...
# 78020     Southeast        Reseller                            0
# 78021     Northeast        Reseller                            0
# 78022     Southeast        Reseller                            0
# 78023     Southeast    Fields Sales                            0
# 78024  Mid-Atlantic        Reseller                            0
#
#       Opportunity Result  Sales Stage Change Count  \
# 0                    Won                        13
# 1                   Loss                         2
# 2                    Won                         7
# 3                   Loss                         5
# 4                   Loss                        11
# ...                  ...                       ...
# 78020               Loss                         2
# 78021                Won                         1
# 78022               Loss                         2
# 78023               Loss                         2
# 78024               Loss                         1
#
#        Total Days Identified Through Closing  \
# 0                                        104
# 1                                        163
# 2                                         82
# 3                                        124
# 4                                         91
# ...                                      ...
# 78020                                      0
# 78021                                      0
# 78022                                      0
# 78023                                      0
# 78024                                      0
#
#        Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                          101                       0
# 1                                          163                       0
# 2                                           82                    7750
# 3                                          124                       0
# 4                                           13                   69756
# ...                                        ...                     ...
# 78020                                        0                  250000
# 78021                                        0                  180000
# 78022                                        0                   90000
# 78023                                        0                  120000
# 78024                                        0                   90000
#
#        Client Size By Revenue  Client Size By Employee Count  \
# 0                           5                              5
# 1                           3                              5
# 2                           1                              1
# 3                           1                              1
# 4                           1                              1
# ...                       ...                            ...
# 78020                       1                              1
# 78021                       1                              1
# 78022                       1                              1
# 78023                       1                              1
# 78024                       1                              1
#
#        Revenue From Client Past Two Years Competitor Type  \
# 0                                       0         Unknown
# 1                                       0         Unknown
# 2                                       0         Unknown
# 3                                       0           Known
# 4                                       0         Unknown
# ...                                   ...             ...
# 78020                                   3         Unknown
# 78021                                   0         Unknown
# 78022                                   0         Unknown
# 78023                                   0         Unknown
# 78024                                   0         Unknown
#
#        Ratio Days Identified To Total Days  \
# 0                                  0.69636
# 1                                  0.00000
# 2                                  1.00000
# 3                                  1.00000
# 4                                  0.00000
# ...                                    ...
# 78020                              0.00000
# 78021                              0.00000
# 78022                              0.00000
# 78023                              1.00000
# 78024                              0.00000
#
#        Ratio Days Validated To Total Days  Ratio Days Qualified To Total Days  \
# 0                                0.113985                            0.154215
# 1                                1.000000                            0.000000
# 2                                0.000000                            0.000000
# 3                                0.000000                            0.000000
# 4                                0.141125                            0.000000
# ...                                   ...                                 ...
# 78020                            0.000000                            0.000000
# 78021                            0.000000                            0.000000
# 78022                            0.000000                            0.000000
# 78023                            0.000000                            0.000000
# 78024                            0.000000                            0.000000
#
#        Deal Size Category  Opportunity
# 0                       1            1
# 1                       1            0
# 2                       1            1
# 3                       1            0
# 4                       4            0
# ...                   ...          ...
# 78020                   6            0
# 78021                   5            1
# 78022                   4            0
# 78023                   5            0
# 78024                   4            0
#
# [78025 rows x 20 columns]

# %%
X = data[['Elapsed Days In Sales Stage','Sales Stage Change Count', 'Total Days Identified Through Closing', 
        'Total Days Identified Through Qualified']]
y = data['Opportunity']

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size = 0.7,
                                                    stratify=y,
                                                    random_state=123)

print(y_train)
print(y_test)
# Out:
# 7932     0
# 73630    1
# 77018    1
# 32489    0
# 36844    0
#         ..
# 33542    0
# 62011    0
# 66094    0
# 12509    0
# 71638    0
# Name: Opportunity, Length: 59970, dtype: int32
# 75038    1
# 31789    1
# 47187    1
# 46853    1
# 52351    1
#         ..
# 26762    1
# 14359    1
# 42812    1
# 66130    1
# 41896    1
# Name: Opportunity, Length: 1578, dtype: int32

# %%
np.bincount(y_train)
#print('Training : ', np.bincount(y_train) / float(len(y_train)) * 100.0)
#print('Testing : ', np.bincount(y_test) / float(len(y_test)) * 100.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-5ec203b2ffb3> in <module>
# ----> 1 np.bincount(y_train)
#       2 #print('Training : ', np.bincount(y_train) / float(len(y_train)) * 100.0)
#       3 #print('Testing : ', np.bincount(y_test) / float(len(y_test)) * 100.0)
#
# C:\Anaconda3\envs\DataScience\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     946             warnings.warn(msg, FutureWarning, stacklevel=3)
#     947             dtype = "M8[ns]"
# --> 948         return np.asarray(self.array, dtype)
#     949
#     950     # ----------------------------------------------------------------------
#
# C:\Anaconda3\envs\DataScience\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# C:\Anaconda3\envs\DataScience\lib\site-packages\pandas\core\arrays\numpy_.py in __array__(self, dtype)
#     164
#     165     def __array__(self, dtype=None):
# --> 166         return np.asarray(self._ndarray, dtype=dtype)
#     167
#     168     _HANDLED_TYPES = (np.ndarray, numbers.Number)
#
# C:\Anaconda3\envs\DataScience\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: invalid literal for int() with base 10: 'Loss'

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print(X_train)
print(y_train)
# Out:
# [[-0.47293907 -0.63607194 -0.88957124 -0.87469022]
#  [ 0.76783569 -0.63607194 -0.23530176 -0.21372334]
#  [ 1.5198204   0.03631589 -0.88957124 -0.87469022]
#  ...
#  [-0.92412989  0.03631589 -0.35425984 -0.69442653]
#  [ 0.20384717 -0.63607194  0.53792582  0.56741933]
#  [ 0.69263722 -0.63607194  2.85760854  2.91084734]]
# 37117    0
# 17375    0
# 12342    0
# 24211    0
# 71574    0
#         ..
# 48503    0
# 57786    0
# 72353    0
# 18315    0
# 1081     0
# Name: Opportunity, Length: 59970, dtype: int32

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(4),solver='lbfgs',activation='tanh',
                    random_state=150,learning_rate_init=0.01,max_iter=500)
#help(mlp)

# %%
mlp.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='tanh', alpha=0.0001, batch_size='auto', beta_1=0.9,
#               beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=4, learning_rate='constant',
#               learning_rate_init=0.01, max_iter=500, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=150, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

print("Predicting Win/Loss on the test set using Multi-Layer Precepiton")

y_pred = mlp.predict(X_test)

print("Accurary : ", round(accuracy_score(y_test, y_pred),4))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Predicting Win/Loss on the test set using Multi-Layer Precepiton
# Accurary :  0.8249
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89     18089
#            1       0.68      0.44      0.53      5319
#
#     accuracy                           0.82     23408
#    macro avg       0.76      0.69      0.71     23408
# weighted avg       0.81      0.82      0.81     23408
#
# [[16989  1100]
#  [ 2999  2320]]

# %%
import scikitplot as skplt
skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=True)
plt.show()

# %%
from sklearn.metrics import roc_auc_score
# calculate AUC
auc = roc_auc_score(y_test, y_pred)
print('AUC: %.3f' % auc)

# AUC: the higher the better -> close to 1
# Out:
# AUC: 0.688

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from matplotlib import pyplot
# calculate roc curve
y_pred_prob = mlp.predict_proba(X_test)[:, 1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
# plot no skill
pyplot.plot([0, 1], [0, 1], linestyle='--')
# plot the roc curve for the model
pyplot.plot(fpr, tpr, marker='.')
# show the plot
pyplot.show()

# Intepret: TPR (True Positive Rate) high, TNR high
# the graph below is used for comparing different models
